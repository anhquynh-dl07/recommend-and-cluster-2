# %%
# thêm stop word
new_stop_words = [] # thêm stop word nếu cần
stop_words = stop_words + [new_word for new_word in new_stop_words if new_word not in stop_words]

# %%
text = 'bán nốt nhạc zalo inbox giàlô hình ảnh sản_phẩm chay di_hoc lái ảnh thích_hợp yên_chí yên_tâm thiện_chí'

# %%
words = text.split(' ')
words
# Out:
# ['bán',
#  'nốt',
#  'nhạc',
#  'zalo',
#  'inbox',
#  'giàlô',
#  'hình',
#  'ảnh',
#  'sản_phẩm',
#  'chay',
#  'di_hoc',
#  'lái',
#  'ảnh',
#  'thích_hợp',
#  'yên_chí',
#  'yên_tâm',
#  'thiện_chí']

# %%
new_words = [word.replace('_', ' ') for word in words]

new_words
# Out:
# ['bán',
#  'nốt',
#  'nhạc',
#  'zalo',
#  'inbox',
#  'giàlô',
#  'hình',
#  'ảnh',
#  'sản phẩm',
#  'chay',
#  'di hoc',
#  'lái',
#  'ảnh',
#  'thích hợp',
#  'yên chí',
#  'yên tâm',
#  'thiện chí']
